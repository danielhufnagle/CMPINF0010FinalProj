# %% [markdown]
# # Courts and Rinks

# %% [markdown]
# ### Import dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read in data

# %%
data = pd.read_csv('data/courts-rinks.csv')
data.head()
# Out:
#    _id          id                                   name               type  \
# 0    1  1592343416   Allegheny Commons Basketball Court 1  Basketball (Full)
# 1    2  1365248699  Allegheny Commons Park Tennis Court 1             Tennis
# 2    3  1757180821  Allegheny Commons Park Tennis Court 2             Tennis
# 3    4   744303307  Allegheny Commons Park Tennis Court 3             Tennis
# 4    5  1157777481          Alton Park Basketball Court 1  Basketball (Half)
#
#                 park location surface_material  grandstand inactive  \
# 0  Allegheny Commons      NaN              NaN           0        f
# 1  Allegheny Commons      NaN          Asphalt           0        f
# 2  Allegheny Commons      NaN          Asphalt           0        f
# 3  Allegheny Commons      NaN          Asphalt           0        f
# 4         Alton Park      NaN          Asphalt           0        f
#
#        neighborhood  council_district  ward        tract  \
# 0  Allegheny Center                 1    22  42003562700
# 1  Allegheny Center                 1    22  42003562700
# 2  Allegheny Center                 1    22  42003562700
# 3  Allegheny Center                 1    22  42003562700
# 4         Beechview                 4    19  42003191600
#
#    public_works_division  pli_division  police_zone fire_zone   latitude  \
# 0                      1            22            1       1-7  40.454443
# 1                      1            22            1       1-7  40.452400
# 2                      1            22            1       1-7  40.452238
# 3                      1            22            1       1-7  40.452075
# 4                      5            19            6      4-28  40.414152
#
#    longitude
# 0 -80.008104
# 1 -80.012531
# 2 -80.012150
# 3 -80.011767
# 4 -80.022305

# %% [markdown]
# ### Isolate potentially useful data

# %%
data = data[['type', 'park', 'neighborhood']]
data.head()
# Out:
#                 type               park      neighborhood
# 0  Basketball (Full)  Allegheny Commons  Allegheny Center
# 1             Tennis  Allegheny Commons  Allegheny Center
# 2             Tennis  Allegheny Commons  Allegheny Center
# 3             Tennis  Allegheny Commons  Allegheny Center
# 4  Basketball (Half)         Alton Park         Beechview

# %% [markdown]
# ### Collect Court + Rink Frequency By Neighborhood

# %%
neighborhoods = {}
for index, row in data.iterrows():
    if row['neighborhood'] not in neighborhoods.keys():
        neighborhoods[row['neighborhood']] = 0
    neighborhoods[row['neighborhood']] += 1
neighborhoods
# Out:
# {'Allegheny Center': 9,
#  'Beechview': 7,
#  'Bedford Dwellings': 2,
#  'South Side Slopes': 6,
#  'South Side Flats': 5,
#  'Lower Lawrenceville': 6,
#  'Crawford-Roberts': 2,
#  'Banksville': 3,
#  'Bon Air': 1,
#  'Central Oakland': 1,
#  'Brighton Heights': 2,
#  'Brookline': 9,
#  'Hazelwood': 10,
#  'Lincoln-Lemington-Belmar': 2,
#  'Troy Hill': 8,
#  'Perry South': 1,
#  'Homewood West': 1,
#  'Squirrel Hill South': 26,
#  'Strip District': 1,
#  'Stanton Heights': 2,
#  'Crafton Heights': 3,
#  'Upper Lawrenceville': 2,
#  'East Carnegie': 2,
#  'East Hills': 2,
#  'Duquesne Heights': 2,
#  'Allentown': 1,
#  'Mount Washington': 5,
#  'East Liberty': 6,
#  'Fairywood': 2,
#  'Fineview': 2,
#  'Garfield': 3,
#  'Greenfield': 5,
#  'South Oakland': 2,
#  'Point Breeze': 2,
#  'Regent Square': 6,
#  'Hays': 1,
#  'Elliott': 5,
#  'Morningside': 4,
#  'Highland Park': 20,
#  'Central Northside': 2,
#  'Terrace Village': 5,
#  'Larimer': 1,
#  'Spring Hill-City View': 4,
#  'Carrick': 3,
#  'Central Lawrenceville': 1,
#  'Manchester': 6,
#  'Marshall-Shadeland': 1,
#  'Lincoln Place': 4,
#  'Sheraden': 6,
#  'Beltzhoover': 9,
#  'Shadyside': 2,
#  'Oakwood': 3,
#  'Bloomfield': 5,
#  'Upper Hill': 1,
#  'New Homestead': 2,
#  'Spring Garden': 2,
#  'Middle Hill': 1,
#  'West End': 2,
#  'Polish Hill': 1,
#  'Squirrel Hill North': 1,
#  'Point Breeze North': 1,
#  'Swisshelm Park': 2,
#  'Perry North': 2}

# %%
n_series = pd.Series(neighborhoods)
len(n_series)
# Out:
# 63

# %% [markdown]
# ### Plot Data

# %%
plt.rcParams.update({'font.size': 5})
n_series.plot.bar(rot=90)
plt.title('Number of Courts and Rinks by Neighborhood of Pittsburgh')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Courts and Rinks')
# Out:
# Text(0, 0.5, 'Number of Courts and Rinks')

# %% [markdown]
# ##### Enlarging the graphs (by just only taking a third of the data at a time)

# %%
n_series[:21].plot.bar(rot=90)
plt.title('Number of Courts and Rinks by Neighborhood of Pittsburgh')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Courts and Rinks')
# Out:
# Text(0, 0.5, 'Number of Courts and Rinks')

# %%
n_series[21:42].plot.bar(rot=90)
plt.title('Number of Courts and Rinks by Neighborhood of Pittsburgh')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Courts and Rinks')
# Out:
# Text(0, 0.5, 'Number of Courts and Rinks')

# %%
n_series[42:].plot.bar(rot=90)
plt.title('Number of Courts and Rinks by Neighborhood of Pittsburgh')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Courts and Rinks')
# Out:
# Text(0, 0.5, 'Number of Courts and Rinks')

# %% [markdown]
# ### Getting Rankings
#
# Top 3 rankings

# %%
top_names = []
top_numbers = []

for i in range(len(neighborhoods)):
    best = max(neighborhoods, key=neighborhoods.get)
    top_names.append(best)
    top_numbers.append(neighborhoods[best])
    neighborhoods[best] = 0

print('The overall ranking is: ')
for i in range(len(top_names)):
    print(top_names[i], ':', top_numbers[i])
# Out:
# The overall ranking is:
# Squirrel Hill South : 26
# Highland Park : 20
# Hazelwood : 10
# Allegheny Center : 9
# Brookline : 9
# Beltzhoover : 9
# Troy Hill : 8
# Beechview : 7
# South Side Slopes : 6
# Lower Lawrenceville : 6
# East Liberty : 6
# Regent Square : 6
# Manchester : 6
# Sheraden : 6
# South Side Flats : 5
# Mount Washington : 5
# Greenfield : 5
# Elliott : 5
# Terrace Village : 5
# Bloomfield : 5
# Morningside : 4
# Spring Hill-City View : 4
# Lincoln Place : 4
# Banksville : 3
# Crafton Heights : 3
# Garfield : 3
# Carrick : 3
# Oakwood : 3
# Bedford Dwellings : 2
# Crawford-Roberts : 2
# Brighton Heights : 2
# Lincoln-Lemington-Belmar : 2
# Stanton Heights : 2
# Upper Lawrenceville : 2
# East Carnegie : 2
# East Hills : 2
# Duquesne Heights : 2
# Fairywood : 2
# Fineview : 2
# South Oakland : 2
# Point Breeze : 2
# Central Northside : 2
# Shadyside : 2
# New Homestead : 2
# Spring Garden : 2
# West End : 2
# Swisshelm Park : 2
# Perry North : 2
# Bon Air : 1
# Central Oakland : 1
# Perry South : 1
# Homewood West : 1
# Strip District : 1
# Allentown : 1
# Hays : 1
# Larimer : 1
# Central Lawrenceville : 1
# Marshall-Shadeland : 1
# Upper Hill : 1
# Middle Hill : 1
# Polish Hill : 1
# Squirrel Hill North : 1
# Point Breeze North : 1
